# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/PhD/Linear regression/training_data.csv')
df
# Out:
#              word  speaker  emotion  time position  target sentence  \
# 0           imamo        1        0   0.6        b               25
# 1             još        1        0   0.1        m               25
# 2          četiri        1        0   0.2        e               25
# 3          minuta        1        0   0.8        e               25
# 4      vremena do        1        0   0.3        e               25
# ...           ...      ...      ...   ...      ...              ...
# 75781        dugo     1052        4   1.1        b               40
# 75782     vremena     1052        4   0.6        m               40
# 75783       nismo     1052        4   0.3        e               40
# 75784        ovde     1052        4   0.5        e               40
# 75785        bili     1052        4   0.5        e               40
#
#       speaker gender  length  surprisal GPT  surprisal BERT  log probability  \
# 0                  f     5.0      19.857792        3.380102        -6.051349
# 1                  f     3.0      31.651057        0.000163        -7.325636
# 2                  f     6.0      50.446848        0.000199        -8.268886
# 3                  f     6.0      22.568617        0.000554        -9.569658
# 4                  f     9.0      32.872915        0.000472       -13.097782
# ...              ...     ...            ...             ...              ...
# 75781              m     4.0      19.776289        2.703350        -9.523365
# 75782              m     7.0      40.858231        0.000097        -7.027754
# 75783              m     5.0      22.771593        0.067076        -3.028636
# 75784              m     4.0      18.642887        0.592845        -9.364560
# 75785              m     4.0      24.994622        0.126511        -3.028636
#
#        fold
# 0         7
# 1         7
# 2         7
# 3         7
# 4         7
# ...     ...
# 75781     4
# 75782     4
# 75783     4
# 75784     4
# 75785     4
#
# [75786 rows x 12 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
mse_list = []
results_df = pd.DataFrame(columns = df.columns.tolist().append('baseline'))

for fold in df['fold'].unique():

    test_data = df[df['fold'] == fold]
    y_test = df[df['fold'] == fold][['time']]

    train_data = df[df['fold'] != fold]
    y_train = df[df['fold'] != fold][['time']]

    model = LinearRegression()
    model.fit(train_data[['length', 'log probability']], y_train)

    y_pred = model.predict(test_data[['length', 'log probability']])

    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)

    test_data.loc[:, 'baseline'] = y_pred
    # Concatenate the DataFrames along rows (axis=0)
    results_df = pd.concat([results_df, test_data], axis=0)


# Calculate the average of mse_list
average_mse = sum(mse_list) / len(mse_list)
# Out:
# Fold: 7  Mean Squared Error: 0.07301882732029293
# Fold: 9  Mean Squared Error: 0.055226461217464544
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# Fold: 6  Mean Squared Error: 0.06204145924641629
# Fold: 3  Mean Squared Error: 0.0657302647165626
# Fold: 5  Mean Squared Error: 0.059464799737533325
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# Fold: 4  Mean Squared Error: 0.06151443378055533
# Fold: 2  Mean Squared Error: 0.07791801500647356
# Fold: 8  Mean Squared Error: 0.06657435077797459
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# Fold: 0  Mean Squared Error: 0.051702744217806774
# Fold: 1  Mean Squared Error: 0.053904496176818174
# Average MSE: 0.06270958521978981
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred
# <ipython-input-6-5c523816ff1f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.loc[:, 'baseline'] = y_pred

# %%
for f, mse in zip(df['fold'].unique(),mse_list):
  print(f"Fold: {f}  MSE: {mse}")
print(f"Average mse over folds: {average_mse}")
# Out:
# Fold: 7  MSE: 0.07301882732029293
# Fold: 9  MSE: 0.055226461217464544
# Fold: 6  MSE: 0.06204145924641629
# Fold: 3  MSE: 0.0657302647165626
# Fold: 5  MSE: 0.059464799737533325
# Fold: 4  MSE: 0.06151443378055533
# Fold: 2  MSE: 0.07791801500647356
# Fold: 8  MSE: 0.06657435077797459
# Fold: 0  MSE: 0.051702744217806774
# Fold: 1  MSE: 0.053904496176818174
# Average mse over folds: 0.06270958521978981

# %%
results_df
# Out:
#              word  speaker  emotion  time position  target sentence  \
# 0           imamo        1        0   0.6        b               25
# 1             još        1        0   0.1        m               25
# 2          četiri        1        0   0.2        e               25
# 3          minuta        1        0   0.8        e               25
# 4      vremena do        1        0   0.3        e               25
# ...           ...      ...      ...   ...      ...              ...
# 75770      donese     1052        4   0.2        e               38
# 75771      odluku     1052        4   0.8        e               38
# 75772           o     1052        4   0.1        e               38
# 75773    njegovoj     1052        4   0.4        e               38
# 75774       smeni     1052        4   0.4        e               38
#
#       speaker gender  length  surprisal GPT  surprisal BERT  log probability  \
# 0                  f     5.0      19.857792    3.380102e+00        -6.051349
# 1                  f     3.0      31.651057    1.627048e-04        -7.325636
# 2                  f     6.0      50.446848    1.993417e-04        -8.268886
# 3                  f     6.0      22.568617    5.535464e-04        -9.569658
# 4                  f     9.0      32.872915    4.718853e-04       -13.097782
# ...              ...     ...            ...             ...              ...
# 75770              m     6.0      21.093443    1.265704e+00       -11.516400
# 75771              m     6.0      33.347344    3.223444e-03        -8.857048
# 75772              m     1.0       7.940099    5.159480e-07        -6.484565
# 75773              m     8.0      54.498621    2.224697e-02        -6.630206
# 75774              m     5.0      26.880530    5.288708e-01       -11.130538
#
#        fold  baseline
# 0         7  0.394550
# 1         7  0.289565
# 2         7  0.474390
# 3         7  0.486852
# 4         7  0.696440
# ...     ...       ...
# 75770     1  0.509190
# 75771     1  0.479364
# 75772     1  0.174174
# 75773     1  0.565821
# 75774     1  0.449146
#
# [75786 rows x 13 columns]

# %%
results_df.to_csv('/content/drive/MyDrive/PhD/Linear regression/training_data.csv', index=False)
