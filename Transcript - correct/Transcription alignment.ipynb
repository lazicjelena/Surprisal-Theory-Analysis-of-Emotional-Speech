# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from difflib import SequenceMatcher
import pandas as pd
from fuzzywuzzy import fuzz
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
target_sentences_df = pd.read_csv('/content/drive/MyDrive/PhD/Transcript - correct/target_sentences.csv')
target_sentences_df
# Out:
#                                                  Text
# 0                               još malo pa će izbori
# 1                 naoblačilo se kao da će padati kiša
# 2                        naša kola su stara 10 godina
# 3   otišao je u inostranstvo prošle godine i još s...
# 4              telefoni zvone po ceo dan i tebe traže
# ..                                                ...
# 62                   pojavio se u poslednjem trenutku
# 63                         sanjao sam te pre neku noć
# 64                   premijer je obećao viši standard
# 65                         sutra je doček Nove Godine
# 66                                           nadam se
#
# [67 rows x 1 columns]

# %%
wrong_transcription_df = pd.read_csv('/content/drive/MyDrive/PhD/Transcript - correct/wrong_transcription.csv')
print(wrong_transcription_df)
# Out:
#                                       Wrong Sentences
# 0                                 ako ćemo da imitira
# 1                    futur filmovi nisu pisali danima
# 2                      nismo koncertu više tokom dana
# 3   gotovo je sve možete početi da pričam ili da s...
# 4                         čime prati lice da mi treba
# 5                                jesi otišao na vrata
# 6                        hotel perionice pisala jedan
# 7                                  makar traži šta da
# 8               fotografije Nina videću kisele danima
# 9                              jučer si glupa ne vidi
# 10                                       često komerc
# 11                                   ako treba i Mica
# 12                        Thomas racija su opet plače
# 13                      šimšir je oficijalni sikandar
# 14                             pojavio se Po snimcima
# 15                        pojavljuje se u poseti radu
# 16              OK si granice preko puta nas ti dragi
# 17                                zadatak tri planine
# 18                                  Premier ja bet365
# 19                                         meni tiram
# 20                                       on mi poslao

# %%
def align_words(sentence1, sentence2):

    # Tokenize sentences into lowercase words
    words1 = sentence1.split()
    words2 = sentence2.split()

    # Use SequenceMatcher to get matching blocks
    matcher = SequenceMatcher(None, words1, words2)
    matching_blocks = matcher.get_matching_blocks()

    # Extract aligned words
    aligned_words = []

    for block in matching_blocks:
        start_idx1, start_idx2, block_size = block
        aligned_words.extend(zip(words1[start_idx1:start_idx1 + block_size], words2[start_idx2:start_idx2 + block_size]))

    return aligned_words

# %%
def sum_position_of_the_same_chars(word1, word2):
    # Ensure both words are of the same length
    min_len = min(len(word1), len(word2))
    word1 = word1[:min_len]
    word2 = word2[:min_len]

    # Calculate the sum of positions of differing characters
    sum_positions = 0
    for c1, c2 in zip(word1[:min_len], word2[:min_len]):
      if c1 == c2:
        sum_positions +=1

    return sum_positions + len(word1) + len(word2) - 2*min_len

# %%
def pair_words_with_difference(sentence, target_sentence, max_difference=2):
    # Tokenize sentences into lowercase words
    words1 = sentence.split()
    words2 = target_sentence.split()

    # Group unmatched words that have all except one character the same
    grouped_words = []
    paired_words1 = set()
    paired_words2 = set()

    for word1 in words1:
        for word2 in words2:
            if word1 in paired_words1:
              continue  # Skip already paired word1
            if word2 in paired_words2:
                continue  # Skip already paired word2

            sim_count = sum_position_of_the_same_chars(word1, word2)
            if max_difference >= max(len(word1), len(word2)) - sim_count:
                grouped_words.append((word1, word2))
                paired_words1.add(word1)
                paired_words2.add(word2)

    return grouped_words

# %%
def align_endpoints(sentence1, sentence2, aligned_words):

    # Get the indices of aligned words in each sentence
    aligned_indices_s1 = []
    aligned_indices_s2 = []
    max_number1 = -1
    max_number2 = -1
    for pair in aligned_words:
      indices_s1 = [index for index, word in enumerate(sentence1.split()) if word == pair[0]]
      indices_s2 = [index for index, word in enumerate(sentence2.split()) if word == pair[1]]
      # Ensure the number added to aligned_indices_s1 is larger than any number in the list
      smallest_number1 = [num for num in indices_s1 if num > max_number1]
      smallest_number2 = [num for num in indices_s2 if num > max_number2]
     # Add the larger_number to aligned_indices_s1
      aligned_indices_s1.append(min(smallest_number1))
      aligned_indices_s2.append(min(smallest_number2))
     # Find the minimum number from indices_s1
      max_number1 = max(aligned_indices_s1)
      max_number2 = max(aligned_indices_s2)

    # Get the words before the first aligned word in each sentence
    unaligned_words_s1_start = sentence1.split()[:min(aligned_indices_s1)]
    unaligned_words_s2_start = sentence2.split()[:min(aligned_indices_s2)]

    # Get the words after the last aligned word in each sentence
    unaligned_words_s1_end = sentence1.split()[max(aligned_indices_s1) + 1:]
    unaligned_words_s2_end = sentence2.split()[max(aligned_indices_s2) + 1:]

    # Convert tuples to lists for modification
    aligned_words_list = [list(pair) for pair in aligned_words]

    # Modify the first pair if needed
    left_start_s1 = ' '.join(unaligned_words_s1_start)
    left_start_s2 = ' '.join(unaligned_words_s2_start)
    if left_start_s1 != '' and left_start_s2 == '':
        aligned_words_list[0][0] = left_start_s1 + ' ' + aligned_words_list[0][0]
    if left_start_s2 != '' and left_start_s1 == '':
        aligned_words_list[0][1] = left_start_s2 + ' ' + aligned_words_list[0][1]

    # Modify the last pair if needed
    left_end_s1 = ' '.join(unaligned_words_s1_end)
    left_end_s2 = ' '.join(unaligned_words_s2_end)
    if left_end_s1 != '' and left_end_s2 == '':
        aligned_words_list[-1][0] = aligned_words_list[-1][0] + ' ' + left_end_s1
    if left_end_s2 != '' and left_end_s1 == '':
        aligned_words_list[-1][1] = aligned_words_list[-1][1] + ' ' + left_end_s2

    # Convert lists back to tuples
    aligned_words_list = [tuple(map(str.strip, pair)) for pair in aligned_words_list]
    aligned_words = [tuple(pair) for pair in aligned_words_list]

    # Create extended aligned pairs
    extended_aligned_pairs_start = [(' '.join(unaligned_words_s1_start), ' '.join(unaligned_words_s2_start))]
    extended_aligned_pairs_end = [(' '.join(unaligned_words_s1_end), ' '.join(unaligned_words_s2_end))]
    extended_aligned_pairs = extended_aligned_pairs_start + aligned_words + extended_aligned_pairs_end

    # Filter out empty pairs
    extended_aligned_pairs = [pair for pair in extended_aligned_pairs if all(word != '' for word in pair)]

    return extended_aligned_pairs

# %%
def align_middlepoints(sentence1, sentence2, extended_aligned_pairs):
    sentence1 = sentence1.lower()
    sentence2 = sentence2.lower()

    paired_words1 = [word_pair[0] for word_pair in extended_aligned_pairs]
    paired_words2 = [word_pair[1] for word_pair in extended_aligned_pairs]

    words1 = sentence1.split()
    words2 = sentence2.split()

    ind_w1 = 0
    ind_w2 = 0
    ind_pw1 = 0
    ind_pw2 = 0

    final_pair1 = []
    final_pair2 = []
    pom1 = ''
    pom2 = ''
    while ind_w1 < len(words1) or ind_w2 < len(words2) or ind_pw1 < len(paired_words1) or ind_pw2 < len(paired_words2):
      cond1 = words1[ind_w1] == paired_words1[ind_pw1] or (pom1 + ' ' + words1[ind_w1]).strip() == paired_words1[ind_pw1]
      cond2 = words2[ind_w2] == paired_words2[ind_pw2] or (pom2 + ' ' + words2[ind_w2]).strip() == paired_words2[ind_pw2]
      if cond1 and cond2:
        if pom1 == '' or pom2 == '':
          final_pair1.append((pom1 + ' ' + words1[ind_w1]).strip())
          final_pair2.append((pom2 + ' ' + words2[ind_w2]).strip())
        else:
          final_pair1.append(pom1)
          final_pair2.append(pom2)
          final_pair1.append(words1[ind_w1])
          final_pair2.append(words2[ind_w2])
        ind_w1 += 1
        ind_w2 += 1
        ind_pw1 += 1
        ind_pw2 += 1
        pom1 = ''
        pom2 = ''
      else:
        if not cond2:
          pom2 += ' ' + words2[ind_w2]
          pom2 = pom2.strip()
          ind_w2 += 1
        if not cond1:
          pom1 += ' ' + words1[ind_w1]
          pom1 = pom1.strip()
          ind_w1 += 1


    # Create pairs of unmatched words
    final_pairs = list(zip(final_pair1, final_pair2))

    return final_pairs

# %%
def align_transcript(sentence, target_sentence):

  sentence = sentence.lower()
  target_sentence = target_sentence.lower()

  # alignment of the same utterance units
  aligned_words = align_words(sentence, target_sentence)
  # correct begining and end ofutterance
  if aligned_words == []:
    print('Failed to match, second try')
    aligned_words = pair_words_with_difference(sentence, target_sentence)
  print(aligned_words)
  extended_aligned_pairs = align_endpoints(sentence, target_sentence, aligned_words)
  print(extended_aligned_pairs)
  # correct middle point words
  final_aligned_pairs = align_middlepoints(sentence, target_sentence, extended_aligned_pairs)

  return final_aligned_pairs

# %%
def find_target_sentence(sentence, df):
    max_similarity = 0
    target_sentence = ""

    for _, row in df.iterrows():
        current_similarity = fuzz.ratio(sentence, row['Text'])
        if current_similarity > max_similarity:
            max_similarity = current_similarity
            target_sentence = row['Text']

    return target_sentence

# %%
def correct_sentence(sentence):
    target_sentence = find_target_sentence(sentence, target_sentences_df)
    align_pairs = align_transcript(sentence, target_sentence)
    return target_sentence, align_pairs

# %%
def create_dictionary_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Extracting transcript and word information
    transcript_text = lines[0].strip()[12:]
    words_data = []

    for line in lines[1:]:
        parts = line.strip().split(', ')
        word = parts[0].split(': ')[1]
        start = float(parts[1].split(': ')[1])
        end = float(parts[2].split(': ')[1])

        word_info = {"Word": word, "start": start, "end": end}
        words_data.append(word_info)

    # Creating the dictionary
    transcript_data = {"Transcript": transcript_text, "Words": words_data}

    return transcript_data

# %%
def correct_transcript(file_path):

    transcript_data = create_dictionary_from_file(file_path)
    new_transcript_data = {
        "Words": []
    }

    first_line = transcript_data['Transcript'].strip()
    print(first_line)
    is_sentence_in_wrong_transcription = first_line in wrong_transcription_df['Wrong Sentences'].values
    if is_sentence_in_wrong_transcription:
      print('Wrong Transcription!')
      return new_transcript_data

    transcript_data['Transcript'] = transcript_data['Transcript'].lower()
    first_line = transcript_data['Transcript'].strip()
    target_sentence, aligned_pairs = correct_sentence(first_line)
    target_sentence = target_sentence.lower()

    # Loop through the words in the dictionary and update with aligned pairs
    word_pom = ''
    start_time_pom = ''
    ind_word_info = 0
    ind_aligned_pair = 0

    while ind_word_info < len(transcript_data["Words"]) and ind_aligned_pair < len(aligned_pairs):
        word_info = transcript_data["Words"][ind_word_info]
        word_info['Word'] = word_info['Word'].lower()
        aligned_pair = aligned_pairs[ind_aligned_pair]
        if word_info["Word"] == aligned_pair[0] or word_pom + ' ' + word_info["Word"] == aligned_pair[0]:
          new_word_info = {"Word": aligned_pair[1], "start": word_info["start"], "end": word_info["end"]}
          if start_time_pom != '':
            new_word_info["start"] = start_time_pom
            start_time_pom = ''
            word_pom = ''
          # Append the new word dictionary to the "Words" list
          new_transcript_data["Words"].append(new_word_info)
          ind_aligned_pair += 1
        else:
          if word_pom == '':
            start_time_pom =  word_info["start"]
          word_pom = (word_pom + ' ' + word_info["Word"]).strip()
        ind_word_info += 1

    # Update transcript
    transcript_data['Transcript'] = target_sentence
    transcript_data['Words'] = new_transcript_data['Words']

    # Printing the updated dictionary
    #print('Sentence: ' + first_line)
    #print('Corrected Sentence: ' + transcript_data['Transcript'])
    #print(transcript_data['Words'])

    return transcript_data

# %%
def write_transcript(output_file_path, transcript_data):

    with open(output_file_path, 'w', encoding='utf-8') as file:
        # Writing transcript text
        file.write(f"Transcript: {transcript_data['Transcript']}\n")
        # Writing word information
        for word_info in transcript_data['Words']:
            file.write(f"Word: {word_info['Word']}, start: {word_info['start']}, end: {word_info['end']}\n")
    return

# %%
def process_folder(input_folder, output_folder):

    err = 0
    processed_folders = set()

    for root, dirs, files in os.walk(input_folder):
      for filename in files:
        try:
          file_path = os.path.join(root, filename)
          print(file_path)
          new_text = correct_transcript(file_path)
          if len(new_text['Words']) == 0:
            print(f"Error processing: {file_path}")
            err += 1
            continue

          # Creating the corresponding directory structure in the output path
          relative_path = os.path.relpath(file_path, input_folder)
          output_path = os.path.join(output_folder, relative_path)
          output_dir = os.path.dirname(output_path)

          # Print a message when a new folder is create
          current_folder = os.path.dirname(relative_path)
          if current_folder not in processed_folders:
            print(f"Created folder: {current_folder}")
            processed_folders.add(current_folder)

          # Create the corresponding directory in the output path if it doesn't exist
          os.makedirs(output_dir, exist_ok=True)

          # Write the corrected transcript to the output path
          write_transcript(output_path, new_text)

        except:
          # Open the file in append mode (creates the file if it doesn't exist)
          with open('/content/drive/MyDrive/PhD/Transcript - correct/transcript_corrected/errors.txt', 'a') as file:
          # Add new text lines
            lines_to_add = [file_path]
            file.write("\n".join(lines_to_add))

    print('Number of errors: ' + str(err))
    return

# %%
# Example usage:
input_directory = '/content/drive/MyDrive/PhD/Forced_alignment/transcript'
output_directory = '/content/drive/MyDrive/PhD/Transcript - correct/transcript_corrected'

process_folder(input_directory, output_directory)
# Out:
# Streaming output truncated to the last 5000 lines.
# [('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane')]
# [('prelazi', 'prelazio je'), ('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane'), ('burekdžinica', 'buregdzinice')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_0_SZZD32S__28-04-21-02-35-53_transcript.txt
# dok se saginje Umalo da ga Nescafe ljubim Ford
# [('dok', 'dok'), ('se', 'se'), ('umalo', 'umalo'), ('ga', 'ga'), ('ford', 'ford')]
# [('dok', 'dok'), ('se', 'se'), ('umalo', 'umalo'), ('ga', 'ga'), ('ford', 'ford')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK01S__28-04-21-02-36-08_transcript.txt
# Vratiću se brzo
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK02S__28-04-21-02-36-20_transcript.txt
# ne idem danas u školu
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK03S__28-04-21-02-36-33_transcript.txt
# spavaću ceo dan
# [('ceo', 'ceo'), ('dan', 'dan')]
# [('spavaću', 'prespavaću'), ('ceo', 'ceo'), ('dan', 'dan')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK04S__28-04-21-02-36-45_transcript.txt
# napisaću mu pismo
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK05S__28-04-21-02-37-00_transcript.txt
# Krećemo za 5 minuta
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK06S__28-04-21-02-37-13_transcript.txt
# doći će na Mirko na ručak
# [('mirko', 'mirko'), ('na', 'na'), ('ručak', 'ručak')]
# [('doći će na', 'doćiće nam'), ('mirko', 'mirko'), ('na', 'na'), ('ručak', 'ručak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK07S__28-04-21-02-37-25_transcript.txt
# još malo pa će izbori
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će'), ('izbori', 'izbori')]
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će'), ('izbori', 'izbori')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK08S__28-04-21-02-37-38_transcript.txt
# sutra će biti 27 u hladu
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27'), ('u', 'u'), ('hladu', 'hladu')]
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27'), ('u', 'u'), ('hladu', 'hladu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK09S__28-04-21-02-37-54_transcript.txt
# povećaj žurka kod komšija
# [('žurka', 'žurka'), ('kod', 'kod'), ('komšija', 'komšija')]
# [('povećaj', 'doveče je'), ('žurka', 'žurka'), ('kod', 'kod'), ('komšija', 'komšija')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK10S__28-04-21-02-38-09_transcript.txt
# za dva dana počinje škola
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK11S__28-04-21-02-38-23_transcript.txt
# od sutra smo sami u kući
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK12S__28-04-21-02-38-37_transcript.txt
# Petar će doći u ponedeljak
# [('petar', 'petar'), ('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# [('petar', 'petar'), ('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK13S__28-04-21-02-38-51_transcript.txt
# moj sin ide prvi put sam na more
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK14S__28-04-21-02-39-05_transcript.txt
# demonstracije su opet počele
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet'), ('počele', 'počele')]
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet'), ('počele', 'počele')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK15S__28-04-21-02-39-18_transcript.txt
# pojavio se u poslednjem trenutku
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK16S__28-04-21-02-39-32_transcript.txt
# Sanjala sam te pre neku noć
# [('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# [('sanjala', 'sanjao'), ('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK17S__28-04-21-02-39-46_transcript.txt
# premijer je obećao viši standard
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('viši', 'viši'), ('standard', 'standard')]
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('viši', 'viši'), ('standard', 'standard')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK18S__28-04-21-02-40-02_transcript.txt
# Opet je pijaca poskupela
# [('opet', 'opet'), ('je', 'je'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# [('opet', 'opet'), ('je', 'je'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK19S__28-04-21-02-40-15_transcript.txt
# večeras najavljuju padavine
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK20S__28-04-21-02-40-28_transcript.txt
# ponedeljak putujem na frušku Goru
# [('ponedeljak', 'ponedeljak'), ('putujem', 'putujem'), ('na', 'na'), ('frušku', 'frušku'), ('goru', 'goru')]
# [('ponedeljak', 'u ponedeljak'), ('putujem', 'putujem'), ('na', 'na'), ('frušku', 'frušku'), ('goru', 'goru')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK21S__28-04-21-02-40-43_transcript.txt
# ma karta važi još dva dana
# [('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# [('ma', 'moja'), ('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK22S__28-04-21-02-40-57_transcript.txt
# naša kolosu stara 10 godina
# [('naša', 'naša'), ('stara', 'stara'), ('10', '10'), ('godina', 'godina')]
# [('naša', 'naša'), ('stara', 'stara'), ('10', '10'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK23S__28-04-21-02-41-12_transcript.txt
# sutra se završava školska godina
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK24S__28-04-21-02-41-25_transcript.txt
# preko leta ću biti u Beogradu
# [('preko', 'preko'), ('leta', 'leta'), ('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# [('preko', 'preko'), ('leta', 'leta'), ('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK25S__28-04-21-02-41-39_transcript.txt
# nismo u kontaktu više od godinu dana
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK26S__28-04-21-02-41-54_transcript.txt
# u braku smo već devet godina
# [('u', 'u'), ('braku', 'braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# [('u', 'u'), ('braku', 'braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK27S__28-04-21-02-42-08_transcript.txt
# salsa minuta počinje predstava
# [('minuta', 'minuta'), ('počinje', 'počinje'), ('predstava', 'predstava')]
# [('salsa', 'za osam'), ('minuta', 'minuta'), ('počinje', 'počinje'), ('predstava', 'predstava')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK28S__28-04-21-02-42-23_transcript.txt
# večeras mora da donese odluku o njegovoj smeni
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK29S__28-04-21-02-42-46_transcript.txt
# o toj aferi novine su pisale danima
# [('o', 'o'), ('toj', 'toj'), ('aferi', 'aferi'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# [('o', 'o'), ('toj', 'toj'), ('aferi', 'aferi'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/3/5_3_1_SZZK30S__28-04-21-02-43-00_transcript.txt
# dugo vremena nismo ovde bili
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD01T__28-04-21-02-43-22_transcript.txt
# imamo još četiri minuta vremena do polaska voza
# [('imamo', 'imamo'), ('još', 'još'), ('četiri', 'četiri'), ('minuta', 'minuta'), ('vremena', 'vremena'), ('do', 'do'), ('polaska', 'polaska'), ('voza', 'voza')]
# [('imamo', 'imamo'), ('još', 'još'), ('četiri', 'četiri'), ('minuta', 'minuta'), ('vremena', 'vremena'), ('do', 'do'), ('polaska', 'polaska'), ('voza', 'voza')]
# Created folder: 1057/4
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD02T__28-04-21-02-43-40_transcript.txt
# sutra ćemo sve raditi ponovo pa šta ispadne
# [('sutra', 'sutra'), ('ćemo', 'ćemo'), ('sve', 'sve'), ('raditi', 'raditi'), ('ponovo', 'ponovo'), ('pa', 'pa'), ('šta', 'šta'), ('ispadne', 'ispadne')]
# [('sutra', 'sutra'), ('ćemo', 'ćemo'), ('sve', 'sve'), ('raditi', 'raditi'), ('ponovo', 'ponovo'), ('pa', 'pa'), ('šta', 'šta'), ('ispadne', 'ispadne')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD03T__28-04-21-02-43-59_transcript.txt
# kompjuteri su prodali u sve oblasti i bez njih se ne može
# [('kompjuteri', 'kompjuteri'), ('su', 'su'), ('u', 'u'), ('sve', 'sve'), ('oblasti', 'oblasti'), ('i', 'i'), ('bez', 'bez'), ('njih', 'njih'), ('se', 'se'), ('ne', 'ne'), ('može', 'može')]
# [('kompjuteri', 'kompjuteri'), ('su', 'su'), ('u', 'u'), ('sve', 'sve'), ('oblasti', 'oblasti'), ('i', 'i'), ('bez', 'bez'), ('njih', 'njih'), ('se', 'se'), ('ne', 'ne'), ('može', 'može')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD04T__28-04-21-02-44-18_transcript.txt
# otišao inostranstvo prošle godine i još se nije vratio
# [('otišao', 'otišao'), ('inostranstvo', 'inostranstvo'), ('prošle', 'prošle'), ('godine', 'godine'), ('i', 'i'), ('još', 'još'), ('se', 'se'), ('nije', 'nije'), ('vratio', 'vratio')]
# [('otišao', 'otišao'), ('inostranstvo', 'inostranstvo'), ('prošle', 'prošle'), ('godine', 'godine'), ('i', 'i'), ('još', 'još'), ('se', 'se'), ('nije', 'nije'), ('vratio', 'vratio')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD05T__28-04-21-02-44-38_transcript.txt
# telefoni zvone po ceo dan i tebe traže
# [('telefoni', 'telefoni'), ('zvone', 'zvone'), ('po', 'po'), ('ceo', 'ceo'), ('dan', 'dan'), ('i', 'i'), ('tebe', 'tebe'), ('traže', 'traže')]
# [('telefoni', 'telefoni'), ('zvone', 'zvone'), ('po', 'po'), ('ceo', 'ceo'), ('dan', 'dan'), ('i', 'i'), ('tebe', 'tebe'), ('traže', 'traže')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD06T__28-04-21-02-44-56_transcript.txt
# popeću se na drvo pa ko me mama ne vidi
# [('popeću', 'popeću'), ('se', 'se'), ('na', 'na'), ('drvo', 'drvo'), ('me', 'me'), ('mama', 'mama'), ('ne', 'ne'), ('vidi', 'vidi')]
# [('popeću', 'popeću'), ('se', 'se'), ('na', 'na'), ('drvo', 'drvo'), ('me', 'me'), ('mama', 'mama'), ('ne', 'ne'), ('vidi', 'vidi')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD07T__28-04-21-02-45-12_transcript.txt
# Ako se setim tebe kad čujem tu pesmu
# [('se', 'se'), ('setim', 'setim'), ('tebe', 'tebe'), ('kad', 'kad'), ('čujem', 'čujem'), ('tu', 'tu'), ('pesmu', 'pesmu')]
# [('ako', 'uvek'), ('se', 'se'), ('setim', 'setim'), ('tebe', 'tebe'), ('kad', 'kad'), ('čujem', 'čujem'), ('tu', 'tu'), ('pesmu', 'pesmu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD08T__28-04-21-02-45-48_transcript.txt
# Da da tako smo se dogovorili
# [('da', 'da'), ('da', 'da'), ('tako', 'tako'), ('smo', 'smo'), ('se', 'se')]
# [('da', 'da'), ('da', 'da'), ('tako', 'tako'), ('smo', 'smo'), ('se', 'se'), ('dogovorili', 'dogovrili')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD09T__28-04-21-02-46-09_transcript.txt
# znam znam Pa meni je 100 puta pričao
# [('znam', 'znam'), ('znam', 'znam'), ('pa', 'pa'), ('meni', 'meni'), ('je', 'je'), ('100', '100'), ('puta', 'puta'), ('pričao', 'pričao')]
# [('znam', 'znam'), ('znam', 'znam'), ('pa', 'pa'), ('meni', 'meni'), ('je', 'je'), ('100', '100'), ('puta', 'puta'), ('pričao', 'pričao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD10T__28-04-21-02-46-29_transcript.txt
# Mirjana rekla da će se uskoro vratiti
# [('mirjana', 'mirjana'), ('rekla', 'rekla'), ('da', 'da'), ('će', 'će'), ('se', 'se'), ('uskoro', 'uskoro'), ('vratiti', 'vratiti')]
# [('mirjana', 'mirjana'), ('rekla', 'rekla'), ('da', 'da'), ('će', 'će'), ('se', 'se'), ('uskoro', 'uskoro'), ('vratiti', 'vratiti')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD11T__28-04-21-02-46-47_transcript.txt
# na more Idemo isto mesto kao i prošle godine
# [('na', 'na'), ('more', 'more'), ('idemo', 'idemo'), ('isto', 'isto'), ('mesto', 'mesto'), ('kao', 'kao'), ('i', 'i'), ('prošle', 'prošle'), ('godine', 'godine')]
# [('na', 'na'), ('more', 'more'), ('idemo', 'idemo'), ('isto', 'isto'), ('mesto', 'mesto'), ('kao', 'kao'), ('i', 'i'), ('prošle', 'prošle'), ('godine', 'godine')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD12T__28-04-21-02-47-03_transcript.txt
# na slavi ćemo imati preko 50 postaju
# [('na', 'na'), ('slavi', 'slavi'), ('ćemo', 'ćemo'), ('imati', 'imati'), ('preko', 'preko'), ('50', '50')]
# [('na', 'na'), ('slavi', 'slavi'), ('ćemo', 'ćemo'), ('imati', 'imati'), ('preko', 'preko'), ('50', '50'), ('postaju', 'gostiju')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD13T__28-04-21-02-47-18_transcript.txt
# raspitaću se pa ću ti javiti
# [('raspitaću', 'raspitaću'), ('se', 'se'), ('pa', 'pa'), ('ću', 'ću'), ('ti', 'ti'), ('javiti', 'javiti')]
# [('raspitaću', 'raspitaću'), ('se', 'se'), ('pa', 'pa'), ('ću', 'ću'), ('ti', 'ti'), ('javiti', 'javiti')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD14T__28-04-21-02-47-32_transcript.txt
# oblačila se kao da će padati kiša
# [('se', 'se'), ('kao', 'kao'), ('da', 'da'), ('će', 'će'), ('padati', 'padati'), ('kiša', 'kiša')]
# [('oblačila', 'naoblačilo'), ('se', 'se'), ('kao', 'kao'), ('da', 'da'), ('će', 'će'), ('padati', 'padati'), ('kiša', 'kiša')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD15T__28-04-21-02-47-48_transcript.txt
# sećam se kada je ulicom Kneza Miloša saobraćao tramvaj
# [('sećam', 'sećam'), ('se', 'se'), ('je', 'je'), ('ulicom', 'ulicom'), ('kneza', 'kneza'), ('miloša', 'miloša'), ('saobraćao', 'saobraćao'), ('tramvaj', 'tramvaj')]
# [('sećam', 'sećam'), ('se', 'se'), ('je', 'je'), ('ulicom', 'ulicom'), ('kneza', 'kneza'), ('miloša', 'miloša'), ('saobraćao', 'saobraćao'), ('tramvaj', 'tramvaj')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD16T__28-04-21-02-48-07_transcript.txt
# na mlade najviše uticaj imaju lica sa estrade kao i sporta
# [('na', 'na'), ('mlade', 'mlade'), ('najviše', 'najviše'), ('imaju', 'imaju'), ('lica', 'lica'), ('sa', 'sa'), ('estrade', 'estrade'), ('kao', 'kao'), ('i', 'i'), ('sporta', 'sporta')]
# [('na', 'na'), ('mlade', 'mlade'), ('najviše', 'najviše'), ('imaju', 'imaju'), ('lica', 'lica'), ('sa', 'sa'), ('estrade', 'estrade'), ('kao', 'kao'), ('i', 'i'), ('sporta', 'sporta')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD17T__28-04-21-02-48-25_transcript.txt
# čim uplata on će doneti robu
# [('čim', 'čim'), ('on', 'on'), ('će', 'će'), ('doneti', 'doneti'), ('robu', 'robu')]
# [('čim', 'čim'), ('on', 'on'), ('će', 'će'), ('doneti', 'doneti'), ('robu', 'robu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD18T__28-04-21-02-48-44_transcript.txt
# nazvat ću te pa ono otprilike za sat vremena
# [('te', 'te'), ('otprilike', 'otprilike'), ('za', 'za'), ('sat', 'sat'), ('vremena', 'vremena')]
# [('nazvat ću', 'nazvaću'), ('te', 'te'), ('otprilike', 'otprilike'), ('za', 'za'), ('sat', 'sat'), ('vremena', 'vremena')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD19T__28-04-21-02-49-02_transcript.txt
# otvara se igraonica preko puta vaše zgrade
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('zgrade', 'zgrade')]
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('zgrade', 'zgrade')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD20T__28-04-21-02-49-19_transcript.txt
# javio se i otišao je na aerodrom
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('je', 'je'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('je', 'je'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD21T__28-04-21-02-49-37_transcript.txt
# samo što sam stigao odmah sam morao da odem na sastanak
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('odmah', 'odmah'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('odmah', 'odmah'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD22T__28-04-21-02-49-54_transcript.txt
# Taman sam krenula da učim a on pozvao
# [('taman', 'taman'), ('sam', 'sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('pozvao', 'pozvao')]
# [('taman', 'taman'), ('sam', 'sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('pozvao', 'pozvao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD23T__28-04-21-02-50-11_transcript.txt
# Strpi se još malo samo što nismo stigli
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD24T__28-04-21-02-50-29_transcript.txt
# ovi klinci su nemoguće niko ih ne može obuzdati
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD25T__28-04-21-02-50-48_transcript.txt
# Miron je ušao u voz nekoliko minuta pre nas
# [('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# [('miron', 'milan'), ('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD26T__28-04-21-02-51-08_transcript.txt
# gotovo je sve možete početi sa priče
# [('gotovo', 'gotovo'), ('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa')]
# [('gotovo', 'gotovo'), ('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa'), ('priče', 'pričom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD27T__28-04-21-02-51-26_transcript.txt
# Kada završiš sa sastankom javiću nam rezultate
# [('kada', 'kada'), ('sa', 'sa'), ('sastankom', 'sastankom'), ('nam', 'nam'), ('rezultate', 'rezultate')]
# [('kada', 'kada'), ('sa', 'sa'), ('sastankom', 'sastankom'), ('nam', 'nam'), ('rezultate', 'rezultate')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD28T__28-04-21-02-51-44_transcript.txt
# malopre sam se čuo sa njim i on je sve ispričao
# [('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('je', 'je'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# [('malopre', 'malo pre'), ('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('je', 'je'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD29T__28-04-21-02-52-02_transcript.txt
# kada se vratim sa posla svratiću do tebe
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD30T__28-04-21-02-52-19_transcript.txt
# Upravo su mi javili da treba da dođem sutra
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD31T__28-04-21-02-52-34_transcript.txt
# prelazi ulicu na srama ne tek renovirane buregdžinice
# [('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane')]
# [('prelazi', 'prelazio je'), ('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane'), ('buregdžinice', 'buregdzinice')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_0_SKMD32T__28-04-21-02-52-51_transcript.txt
# dok se saginje umalo ga našla zaljubim Forza
# [('dok', 'dok'), ('se', 'se'), ('umalo', 'umalo'), ('ga', 'ga')]
# [('dok', 'dok'), ('se', 'se'), ('umalo', 'umalo'), ('ga', 'ga'), ('našla zaljubim forza', 'ne zgazi ljubin ford')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK01T__28-04-21-02-53-07_transcript.txt
# Vratiću se brzo
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK02T__28-04-21-02-53-18_transcript.txt
# ne idem danas u školu
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK03T__28-04-21-02-53-30_transcript.txt
# spavaću ceo dan
# [('ceo', 'ceo'), ('dan', 'dan')]
# [('spavaću', 'prespavaću'), ('ceo', 'ceo'), ('dan', 'dan')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK04T__28-04-21-02-53-42_transcript.txt
# napisaću mu pismo
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK05T__28-04-21-02-53-57_transcript.txt
# Krećemo za 5 minuta
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK06T__28-04-21-02-54-10_transcript.txt
# doći će na Mirko na ručak
# [('mirko', 'mirko'), ('na', 'na'), ('ručak', 'ručak')]
# [('doći će na', 'doćiće nam'), ('mirko', 'mirko'), ('na', 'na'), ('ručak', 'ručak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK07T__28-04-21-02-54-23_transcript.txt
# još malo pa će izbori
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će'), ('izbori', 'izbori')]
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će'), ('izbori', 'izbori')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK08T__28-04-21-02-54-36_transcript.txt
# sutra će biti 27 hladno
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27')]
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27'), ('hladno', 'u hladu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK09T__28-04-21-02-54-50_transcript.txt
# domaće žurka kod komšije
# [('žurka', 'žurka'), ('kod', 'kod')]
# [('domaće', 'doveče je'), ('žurka', 'žurka'), ('kod', 'kod'), ('komšije', 'komšija')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK10T__28-04-21-02-55-03_transcript.txt
# za dva dana počinje škola
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK11T__28-04-21-02-55-15_transcript.txt
# od sutra smo sami u kući
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK12T__28-04-21-02-55-27_transcript.txt
# Petr će doći u ponedeljak
# [('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# [('petr', 'petar'), ('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK13T__28-04-21-02-55-44_transcript.txt
# moj sin ide prvi put sam na more
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK14T__28-04-21-02-55-59_transcript.txt
# demonstracije su opet počele
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet'), ('počele', 'počele')]
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet'), ('počele', 'počele')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK15T__28-04-21-02-56-13_transcript.txt
# pojavio se u poslednjem trenutku
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK16T__28-04-21-02-56-26_transcript.txt
# Sanjala sam te pre neku noć
# [('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# [('sanjala', 'sanjao'), ('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK17T__28-04-21-02-56-42_transcript.txt
# premijer je obećao više standard
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('standard', 'standard')]
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('standard', 'standard')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK18T__28-04-21-02-56-55_transcript.txt
# opet i pijaca poskupela
# [('opet', 'opet'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# [('opet', 'opet'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK19T__28-04-21-02-57-08_transcript.txt
# večeras najavljuju padavine
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK20T__28-04-21-02-57-21_transcript.txt
# u ponedeljak pucaju na Fruška gora
# [('u', 'u'), ('ponedeljak', 'ponedeljak'), ('na', 'na')]
# [('u', 'u'), ('ponedeljak', 'ponedeljak'), ('na', 'na'), ('fruška gora', 'frušku goru')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK21T__28-04-21-02-57-35_transcript.txt
# ma karta važi još dva dana
# [('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# [('ma', 'moja'), ('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK22T__28-04-21-02-57-52_transcript.txt
# naše kolo su staro 10 godina
# [('su', 'su'), ('10', '10'), ('godina', 'godina')]
# [('naše kolo', 'naša kola'), ('su', 'su'), ('10', '10'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK23T__28-04-21-02-58-06_transcript.txt
# sutra se završava školska godina
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK24T__28-04-21-02-58-20_transcript.txt
# tako leto ću biti u Beogradu
# [('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# [('tako leto', 'preko leta'), ('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK25T__28-04-21-02-58-35_transcript.txt
# nismo u kontaktu više od godinu dana
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK26T__28-04-21-02-58-55_transcript.txt
# braku smo već devet godina
# [('braku', 'braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# [('braku', 'u braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK27T__28-04-21-02-59-08_transcript.txt
# za osam minuta počinje predstava
# [('za', 'za'), ('osam', 'osam'), ('minuta', 'minuta'), ('počinje', 'počinje'), ('predstava', 'predstava')]
# [('za', 'za'), ('osam', 'osam'), ('minuta', 'minuta'), ('počinje', 'počinje'), ('predstava', 'predstava')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK28T__28-04-21-02-59-23_transcript.txt
# večeras mora da donese odluku o njegovoj smeni
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK29T__28-04-21-02-59-38_transcript.txt
# o toj aferi novine su pisale danima
# [('o', 'o'), ('toj', 'toj'), ('aferi', 'aferi'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# [('o', 'o'), ('toj', 'toj'), ('aferi', 'aferi'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1057/4/4_4_1_SKMK30T__28-04-21-02-59-55_transcript.txt
# dugo vremena nismo ovde bili
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd01n__28-04-21-05-45-00_transcript.txt
# imamo još četiri minuta vremena do polaska voza
# [('imamo', 'imamo'), ('još', 'još'), ('četiri', 'četiri'), ('minuta', 'minuta'), ('vremena', 'vremena'), ('do', 'do'), ('polaska', 'polaska'), ('voza', 'voza')]
# [('imamo', 'imamo'), ('još', 'još'), ('četiri', 'četiri'), ('minuta', 'minuta'), ('vremena', 'vremena'), ('do', 'do'), ('polaska', 'polaska'), ('voza', 'voza')]
# Created folder: 1058/1
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd02n__28-04-21-05-45-17_transcript.txt
# sutra ćemo sve raditi ponovo pa šta ispadne
# [('sutra', 'sutra'), ('ćemo', 'ćemo'), ('sve', 'sve'), ('raditi', 'raditi'), ('ponovo', 'ponovo'), ('pa', 'pa'), ('šta', 'šta'), ('ispadne', 'ispadne')]
# [('sutra', 'sutra'), ('ćemo', 'ćemo'), ('sve', 'sve'), ('raditi', 'raditi'), ('ponovo', 'ponovo'), ('pa', 'pa'), ('šta', 'šta'), ('ispadne', 'ispadne')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd03n__28-04-21-05-45-34_transcript.txt
# kompjuteri su prodali u sve oblasti bez njih se ne može
# [('kompjuteri', 'kompjuteri'), ('su', 'su'), ('u', 'u'), ('sve', 'sve'), ('oblasti', 'oblasti'), ('bez', 'bez'), ('njih', 'njih'), ('se', 'se'), ('ne', 'ne'), ('može', 'može')]
# [('kompjuteri', 'kompjuteri'), ('su', 'su'), ('u', 'u'), ('sve', 'sve'), ('oblasti', 'oblasti'), ('bez', 'bez'), ('njih', 'njih'), ('se', 'se'), ('ne', 'ne'), ('može', 'može')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd04n__28-04-21-05-45-52_transcript.txt
# Otišao je u inostranstvo prošle godine i još se nije vratio
# [('otišao', 'otišao'), ('je', 'je'), ('u', 'u'), ('inostranstvo', 'inostranstvo'), ('prošle', 'prošle'), ('godine', 'godine'), ('i', 'i'), ('još', 'još'), ('se', 'se'), ('nije', 'nije'), ('vratio', 'vratio')]
# [('otišao', 'otišao'), ('je', 'je'), ('u', 'u'), ('inostranstvo', 'inostranstvo'), ('prošle', 'prošle'), ('godine', 'godine'), ('i', 'i'), ('još', 'još'), ('se', 'se'), ('nije', 'nije'), ('vratio', 'vratio')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd05n__28-04-21-05-46-09_transcript.txt
# telefoni zvone po ceo dan i tebe traže
# [('telefoni', 'telefoni'), ('zvone', 'zvone'), ('po', 'po'), ('ceo', 'ceo'), ('dan', 'dan'), ('i', 'i'), ('tebe', 'tebe'), ('traže', 'traže')]
# [('telefoni', 'telefoni'), ('zvone', 'zvone'), ('po', 'po'), ('ceo', 'ceo'), ('dan', 'dan'), ('i', 'i'), ('tebe', 'tebe'), ('traže', 'traže')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd06n__28-04-21-05-46-25_transcript.txt
# popeću se na drvo ako mi mama ne vidi
# [('popeću', 'popeću'), ('se', 'se'), ('na', 'na'), ('drvo', 'drvo'), ('ako', 'ako'), ('mama', 'mama'), ('ne', 'ne'), ('vidi', 'vidi')]
# [('popeću', 'popeću'), ('se', 'se'), ('na', 'na'), ('drvo', 'drvo'), ('ako', 'ako'), ('mama', 'mama'), ('ne', 'ne'), ('vidi', 'vidi')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd07n__28-04-21-05-46-40_transcript.txt
# uvek se setim tebe kad čujem tu pesmu
# [('uvek', 'uvek'), ('se', 'se'), ('setim', 'setim'), ('tebe', 'tebe'), ('kad', 'kad'), ('čujem', 'čujem'), ('tu', 'tu'), ('pesmu', 'pesmu')]
# [('uvek', 'uvek'), ('se', 'se'), ('setim', 'setim'), ('tebe', 'tebe'), ('kad', 'kad'), ('čujem', 'čujem'), ('tu', 'tu'), ('pesmu', 'pesmu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd08n__28-04-21-05-46-53_transcript.txt
# Da da tako smo se dogovorili
# [('da', 'da'), ('da', 'da'), ('tako', 'tako'), ('smo', 'smo'), ('se', 'se')]
# [('da', 'da'), ('da', 'da'), ('tako', 'tako'), ('smo', 'smo'), ('se', 'se'), ('dogovorili', 'dogovrili')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd09n__28-04-21-05-47-06_transcript.txt
# znam znam Pa meni je 100 puta pričao
# [('znam', 'znam'), ('znam', 'znam'), ('pa', 'pa'), ('meni', 'meni'), ('je', 'je'), ('100', '100'), ('puta', 'puta'), ('pričao', 'pričao')]
# [('znam', 'znam'), ('znam', 'znam'), ('pa', 'pa'), ('meni', 'meni'), ('je', 'je'), ('100', '100'), ('puta', 'puta'), ('pričao', 'pričao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd10n__28-04-21-05-47-21_transcript.txt
# Mirjana je rekla da će se uskoro vratiti
# [('mirjana', 'mirjana'), ('je', 'je'), ('rekla', 'rekla'), ('da', 'da'), ('će', 'će'), ('se', 'se'), ('uskoro', 'uskoro'), ('vratiti', 'vratiti')]
# [('mirjana', 'mirjana'), ('je', 'je'), ('rekla', 'rekla'), ('da', 'da'), ('će', 'će'), ('se', 'se'), ('uskoro', 'uskoro'), ('vratiti', 'vratiti')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd11n__28-04-21-05-47-34_transcript.txt
# na more Idemo u isto mesto kao i prošle godine
# [('na', 'na'), ('more', 'more'), ('idemo', 'idemo'), ('u', 'u'), ('isto', 'isto'), ('mesto', 'mesto'), ('kao', 'kao'), ('i', 'i'), ('prošle', 'prošle'), ('godine', 'godine')]
# [('na', 'na'), ('more', 'more'), ('idemo', 'idemo'), ('u', 'u'), ('isto', 'isto'), ('mesto', 'mesto'), ('kao', 'kao'), ('i', 'i'), ('prošle', 'prošle'), ('godine', 'godine')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd12n__28-04-21-05-47-49_transcript.txt
# slavi ćemo imati preko 50 gostiju
# [('slavi', 'slavi'), ('ćemo', 'ćemo'), ('imati', 'imati'), ('preko', 'preko'), ('50', '50'), ('gostiju', 'gostiju')]
# [('slavi', 'na slavi'), ('ćemo', 'ćemo'), ('imati', 'imati'), ('preko', 'preko'), ('50', '50'), ('gostiju', 'gostiju')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd13n__28-04-21-05-48-07_transcript.txt
# raspitaću se pa ću ti javiti
# [('raspitaću', 'raspitaću'), ('se', 'se'), ('pa', 'pa'), ('ću', 'ću'), ('ti', 'ti'), ('javiti', 'javiti')]
# [('raspitaću', 'raspitaću'), ('se', 'se'), ('pa', 'pa'), ('ću', 'ću'), ('ti', 'ti'), ('javiti', 'javiti')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd14n__28-04-21-05-48-18_transcript.txt
# naoblačilo se kao da će padati kiša
# [('naoblačilo', 'naoblačilo'), ('se', 'se'), ('kao', 'kao'), ('da', 'da'), ('će', 'će'), ('padati', 'padati'), ('kiša', 'kiša')]
# [('naoblačilo', 'naoblačilo'), ('se', 'se'), ('kao', 'kao'), ('da', 'da'), ('će', 'će'), ('padati', 'padati'), ('kiša', 'kiša')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd15n__28-04-21-05-48-43_transcript.txt
# sećam se kada ulicom Kneza Miloša saobraćao tramvaj
# [('sećam', 'sećam'), ('se', 'se'), ('ulicom', 'ulicom'), ('kneza', 'kneza'), ('miloša', 'miloša'), ('saobraćao', 'saobraćao'), ('tramvaj', 'tramvaj')]
# [('sećam', 'sećam'), ('se', 'se'), ('ulicom', 'ulicom'), ('kneza', 'kneza'), ('miloša', 'miloša'), ('saobraćao', 'saobraćao'), ('tramvaj', 'tramvaj')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd16n__28-04-21-05-49-03_transcript.txt
# na mlade najviše uticaj imaju lice sa estrade kao i sporta
# [('na', 'na'), ('mlade', 'mlade'), ('najviše', 'najviše'), ('imaju', 'imaju'), ('sa', 'sa'), ('estrade', 'estrade'), ('kao', 'kao'), ('i', 'i'), ('sporta', 'sporta')]
# [('na', 'na'), ('mlade', 'mlade'), ('najviše', 'najviše'), ('imaju', 'imaju'), ('sa', 'sa'), ('estrade', 'estrade'), ('kao', 'kao'), ('i', 'i'), ('sporta', 'sporta')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd17n__28-04-21-05-49-42_transcript.txt
# čim uplata on će doneti robu
# [('čim', 'čim'), ('on', 'on'), ('će', 'će'), ('doneti', 'doneti'), ('robu', 'robu')]
# [('čim', 'čim'), ('on', 'on'), ('će', 'će'), ('doneti', 'doneti'), ('robu', 'robu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd18n__28-04-21-05-49-54_transcript.txt
# nazvat ću te ponovo otprilike za sat vremena
# [('te', 'te'), ('ponovo', 'ponovo'), ('otprilike', 'otprilike'), ('za', 'za'), ('sat', 'sat'), ('vremena', 'vremena')]
# [('nazvat ću', 'nazvaću'), ('te', 'te'), ('ponovo', 'ponovo'), ('otprilike', 'otprilike'), ('za', 'za'), ('sat', 'sat'), ('vremena', 'vremena')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd19n__28-04-21-05-50-08_transcript.txt
# otvara se igraonica preko puta naše zgrade
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('naše', 'naše'), ('zgrade', 'zgrade')]
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('naše', 'naše'), ('zgrade', 'zgrade')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd20n__28-04-21-05-50-22_transcript.txt
# javio se i otišao je na aerodrom
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('je', 'je'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('je', 'je'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd21n__28-04-21-05-50-34_transcript.txt
# samo što sam stigao odmah sam morao da odem na sastanak
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('odmah', 'odmah'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('odmah', 'odmah'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd22n__28-04-21-05-50-52_transcript.txt
# Taman sam krenula da učim a on me pozvao
# [('taman', 'taman'), ('sam', 'sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('me', 'me'), ('pozvao', 'pozvao')]
# [('taman', 'taman'), ('sam', 'sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('me', 'me'), ('pozvao', 'pozvao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd23n__28-04-21-05-51-17_transcript.txt
# Strpi se još malo samo što nismo stigli
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd24n__28-04-21-05-51-32_transcript.txt
# ovi klinci su nemoguće niko ih ne može obuzdati
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd25n__28-04-21-05-51-45_transcript.txt
# Milan je ušao u voz nekoliko minuta pre nas
# [('milan', 'milan'), ('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# [('milan', 'milan'), ('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd26n__28-04-21-05-52-02_transcript.txt
# pa to je sve možete početi sa pričom
# [('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa'), ('pričom', 'pričom')]
# [('pa to', 'gotovo'), ('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa'), ('pričom', 'pričom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd27n__28-04-21-05-52-15_transcript.txt
# kad završiš sa sastankom Javiće nam rezultate
# [('sa', 'sa'), ('sastankom', 'sastankom'), ('javiće', 'javiće'), ('nam', 'nam'), ('rezultate', 'rezultate')]
# [('kad završiš', 'kada završi'), ('sa', 'sa'), ('sastankom', 'sastankom'), ('javiće', 'javiće'), ('nam', 'nam'), ('rezultate', 'rezultate')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd28n__28-04-21-05-52-29_transcript.txt
# malopre sam se čuo sa njim i on mi sve ispričao
# [('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('mi', 'mi'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# [('malopre', 'malo pre'), ('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('mi', 'mi'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd29n__28-04-21-05-52-43_transcript.txt
# kada se vratim sa posla svratiću do tebe
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd30n__28-04-21-05-52-55_transcript.txt
# Upravo su mi javili da treba da dođem sutra
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd31n__28-04-21-05-53-10_transcript.txt
# prelazio je ulicu naspram one tek renovirane buregdžinice
# [('prelazio', 'prelazio'), ('je', 'je'), ('ulicu', 'ulicu'), ('naspram', 'naspram'), ('one', 'one'), ('tek', 'tek'), ('renovirane', 'renovirane')]
# [('prelazio', 'prelazio'), ('je', 'je'), ('ulicu', 'ulicu'), ('naspram', 'naspram'), ('one', 'one'), ('tek', 'tek'), ('renovirane', 'renovirane'), ('buregdžinice', 'buregdzinice')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_0_mvmd32n__28-04-21-05-53-26_transcript.txt
# dok se saginje u maloga Ne zgazi ljubim Ford
# [('dok', 'dok'), ('se', 'se'), ('ne', 'ne'), ('zgazi', 'zgazi'), ('ford', 'ford')]
# [('dok', 'dok'), ('se', 'se'), ('ne', 'ne'), ('zgazi', 'zgazi'), ('ford', 'ford')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_1_mvmk01n__28-04-21-05-53-38_transcript.txt
# Vratiću se brzo
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1058/1/2_1_1_mvmk02n__28-04-21-05-53-47_transcript.txt
# ne idem danas u školu
# ...
# otvara se igraonica preko puta je naše zgrade
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('naše', 'naše'), ('zgrade', 'zgrade')]
# [('otvara', 'otvara'), ('se', 'se'), ('igraonica', 'igraonica'), ('naše', 'naše'), ('zgrade', 'zgrade')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD20T__19-04-21-09-41-42_transcript.txt
# javio se i otišao na aerodrom
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# [('javio', 'javio'), ('se', 'se'), ('i', 'i'), ('otišao', 'otišao'), ('na', 'na'), ('aerodrom', 'aerodrom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD21T__19-04-21-09-42-02_transcript.txt
# samo što sam stigao ono sam morao da odem na sastanak
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# [('samo', 'samo'), ('što', 'što'), ('sam', 'sam'), ('stigao', 'stigao'), ('sam', 'sam'), ('morao', 'morao'), ('da', 'da'), ('odem', 'odem'), ('na', 'na'), ('sastanak', 'sastanak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD22T__19-04-21-09-42-22_transcript.txt
# sam krenula da učim a on me pozvao
# [('sam', 'sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('me', 'me'), ('pozvao', 'pozvao')]
# [('sam', 'taman sam'), ('krenula', 'krenula'), ('da', 'da'), ('učim', 'učim'), ('a', 'a'), ('on', 'on'), ('me', 'me'), ('pozvao', 'pozvao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD23T__19-04-21-09-42-37_transcript.txt
# Strpi se još malo samo što nismo stigli
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# [('strpi', 'strpi'), ('se', 'se'), ('još', 'još'), ('malo', 'malo'), ('samo', 'samo'), ('što', 'što'), ('stigli', 'stigli')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD24T__19-04-21-09-43-04_transcript.txt
# ovi klinci su nemoguće niko ih ne može obuzdati
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# [('ovi', 'ovi'), ('klinci', 'klinci'), ('su', 'su'), ('niko', 'niko'), ('ih', 'ih'), ('ne', 'ne'), ('može', 'može'), ('obuzdati', 'obuzdati')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD25T__19-04-21-09-43-20_transcript.txt
# Milan je ušao u voz nekoliko minuta pre nas
# [('milan', 'milan'), ('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# [('milan', 'milan'), ('je', 'je'), ('ušao', 'ušao'), ('u', 'u'), ('voz', 'voz'), ('nekoliko', 'nekoliko'), ('minuta', 'minuta'), ('pre', 'pre'), ('nas', 'nas')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD26T__19-04-21-09-43-38_transcript.txt
# gotovo je sve možete početi sa pričom
# [('gotovo', 'gotovo'), ('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa'), ('pričom', 'pričom')]
# [('gotovo', 'gotovo'), ('je', 'je'), ('sve', 'sve'), ('možete', 'možete'), ('početi', 'početi'), ('sa', 'sa'), ('pričom', 'pričom')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD27T__19-04-21-09-43-57_transcript.txt
# završi se sastankom Javiće nam rezultati
# [('završi', 'završi'), ('sastankom', 'sastankom'), ('javiće', 'javiće'), ('nam', 'nam')]
# [('završi', 'kada završi'), ('sastankom', 'sastankom'), ('javiće', 'javiće'), ('nam', 'nam'), ('rezultati', 'rezultate')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD28T__19-04-21-09-44-14_transcript.txt
# malopre sam se čuo sa njim i on mi je sve ispričao
# [('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('mi', 'mi'), ('je', 'je'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# [('malopre', 'malo pre'), ('sam', 'sam'), ('se', 'se'), ('čuo', 'čuo'), ('sa', 'sa'), ('njim', 'njim'), ('i', 'i'), ('on', 'on'), ('mi', 'mi'), ('je', 'je'), ('sve', 'sve'), ('ispričao', 'ispričao')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD29T__19-04-21-09-44-39_transcript.txt
# kada se vratim sa posla svratiću do tebe
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# [('kada', 'kada'), ('se', 'se'), ('vratim', 'vratim'), ('sa', 'sa'), ('posla', 'posla'), ('svratiću', 'svratiću'), ('do', 'do'), ('tebe', 'tebe')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD30T__19-04-21-09-44-56_transcript.txt
# Upravo su mi javili da treba da dođem sutra
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# [('upravo', 'upravo'), ('su', 'su'), ('mi', 'mi'), ('javili', 'javili'), ('da', 'da'), ('treba', 'treba'), ('da', 'da'), ('dođem', 'dođem'), ('sutra', 'sutra')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD31T__19-04-21-09-45-21_transcript.txt
# prolazio je ulicu na spremane tek renovirane buregdžinice
# [('je', 'je'), ('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane')]
# [('prolazio', 'prelazio'), ('je', 'je'), ('ulicu', 'ulicu'), ('tek', 'tek'), ('renovirane', 'renovirane'), ('buregdžinice', 'buregdzinice')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_0_SKMD32T__19-04-21-09-45-41_transcript.txt
# dok se saginjem maloga Ne zgazi ljubim Ford
# [('dok', 'dok'), ('se', 'se'), ('ne', 'ne'), ('zgazi', 'zgazi'), ('ford', 'ford')]
# [('dok', 'dok'), ('se', 'se'), ('ne', 'ne'), ('zgazi', 'zgazi'), ('ford', 'ford')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK01T__19-04-21-09-45-54_transcript.txt
# Vratiću se brzo
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# [('vratiću', 'vratiću'), ('se', 'se'), ('brzo', 'brzo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK02T__19-04-21-09-46-16_transcript.txt
# ne idem danas u školu
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# [('ne', 'ne'), ('idem', 'idem'), ('danas', 'danas'), ('u', 'u'), ('školu', 'školu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK03T__19-04-21-09-46-48_transcript.txt
# prespava ću ceo dan
# [('ceo', 'ceo'), ('dan', 'dan')]
# [('prespava ću', 'prespavaću'), ('ceo', 'ceo'), ('dan', 'dan')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK04T__19-04-21-09-47-06_transcript.txt
# napisaću mu pismo
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# [('napisaću', 'napisaću'), ('mu', 'mu'), ('pismo', 'pismo')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK05T__19-04-21-09-47-26_transcript.txt
# Krećemo za 5 minuta
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# [('krećemo', 'krećemo'), ('za', 'za'), ('minuta', 'minuta')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK06T__19-04-21-09-47-43_transcript.txt
# doći će na mirku na ručak
# [('na', 'na'), ('ručak', 'ručak')]
# [('doći će', 'doćiće nam mirko'), ('na', 'na'), ('ručak', 'ručak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK07T__19-04-21-09-48-04_transcript.txt
# još malo pa će izbor
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će')]
# [('još', 'još'), ('malo', 'malo'), ('pa', 'pa'), ('će', 'će'), ('izbor', 'izbori')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK08T__19-04-21-09-48-19_transcript.txt
# sutra će biti 27 u hladu
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27'), ('u', 'u'), ('hladu', 'hladu')]
# [('sutra', 'sutra'), ('će', 'će'), ('biti', 'biti'), ('27', '27'), ('u', 'u'), ('hladu', 'hladu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK09T__19-04-21-09-48-40_transcript.txt
# doveče je žurka kod komšije
# [('doveče', 'doveče'), ('je', 'je'), ('žurka', 'žurka'), ('kod', 'kod')]
# [('doveče', 'doveče'), ('je', 'je'), ('žurka', 'žurka'), ('kod', 'kod'), ('komšije', 'komšija')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK10T__19-04-21-09-48-59_transcript.txt
# za dva dana počinje škola
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# [('za', 'za'), ('dva', 'dva'), ('dana', 'dana'), ('počinje', 'počinje'), ('škola', 'škola')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK11T__19-04-21-09-49-21_transcript.txt
# od sutra smo sami u kući
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# [('od', 'od'), ('sutra', 'sutra'), ('smo', 'smo'), ('sami', 'sami'), ('u', 'u'), ('kući', 'kući')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK12T__19-04-21-09-49-44_transcript.txt
# Petra će doći u ponedeljak
# [('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# [('petra', 'petar'), ('će', 'će'), ('doći', 'doći'), ('u', 'u'), ('ponedeljak', 'ponedeljak')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK13T__19-04-21-09-50-14_transcript.txt
# moj sin ide prvi put sam na more
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# [('moj', 'moj'), ('sin', 'sin'), ('ide', 'ide'), ('prvi', 'prvi'), ('put', 'put'), ('sam', 'sam'), ('na', 'na'), ('more', 'more')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK14T__19-04-21-09-50-31_transcript.txt
# demonstracije su opet počela
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet')]
# [('demonstracije', 'demonstracije'), ('su', 'su'), ('opet', 'opet'), ('počela', 'počele')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK15T__19-04-21-09-50-44_transcript.txt
# pojavio se u poslednjem trenutku
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# [('pojavio', 'pojavio'), ('se', 'se'), ('u', 'u'), ('poslednjem', 'poslednjem'), ('trenutku', 'trenutku')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK16T__19-04-21-09-51-05_transcript.txt
# Sanjala sam te pre neku noć
# [('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# [('sanjala', 'sanjao'), ('sam', 'sam'), ('te', 'te'), ('pre', 'pre'), ('neku', 'neku'), ('noć', 'noć')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK17T__19-04-21-09-51-22_transcript.txt
# premijer je obećao viši standard
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('viši', 'viši'), ('standard', 'standard')]
# [('premijer', 'premijer'), ('je', 'je'), ('obećao', 'obećao'), ('viši', 'viši'), ('standard', 'standard')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK18T__19-04-21-09-51-40_transcript.txt
# Opet je pijaca poskupela
# [('opet', 'opet'), ('je', 'je'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# [('opet', 'opet'), ('je', 'je'), ('pijaca', 'pijaca'), ('poskupela', 'poskupela')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK19T__19-04-21-09-51-56_transcript.txt
# večeras najavljuju padavine
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# [('večeras', 'večeras'), ('najavljuju', 'najavljuju'), ('padavine', 'padavine')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK20T__19-04-21-09-52-14_transcript.txt
# u ponedeljak putujem na frušku Goru
# [('u', 'u'), ('ponedeljak', 'ponedeljak'), ('putujem', 'putujem'), ('na', 'na'), ('frušku', 'frušku'), ('goru', 'goru')]
# [('u', 'u'), ('ponedeljak', 'ponedeljak'), ('putujem', 'putujem'), ('na', 'na'), ('frušku', 'frušku'), ('goru', 'goru')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK21T__19-04-21-09-52-29_transcript.txt
# moja karta važi još dva dana
# [('moja', 'moja'), ('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# [('moja', 'moja'), ('karta', 'karta'), ('važi', 'važi'), ('još', 'još'), ('dva', 'dva'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK22T__19-04-21-09-52-47_transcript.txt
# naša kola sestara 10 godina
# [('naša', 'naša'), ('kola', 'kola'), ('10', '10'), ('godina', 'godina')]
# [('naša', 'naša'), ('kola', 'kola'), ('10', '10'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK23T__19-04-21-09-53-07_transcript.txt
# sutra se završava školska godina
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# [('sutra', 'sutra'), ('se', 'se'), ('završava', 'završava'), ('školska', 'školska'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK24T__19-04-21-09-53-23_transcript.txt
# preko leta ću biti u Beogradu
# [('preko', 'preko'), ('leta', 'leta'), ('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# [('preko', 'preko'), ('leta', 'leta'), ('ću', 'ću'), ('biti', 'biti'), ('u', 'u'), ('beogradu', 'beogradu')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK25T__19-04-21-09-53-41_transcript.txt
# nismo u kontaktu više od godinu dana
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# [('nismo', 'nismo'), ('u', 'u'), ('kontaktu', 'kontaktu'), ('više', 'više'), ('od', 'od'), ('godinu', 'godinu'), ('dana', 'dana')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK26T__19-04-21-09-54-04_transcript.txt
# u braku smo već devet godina
# [('u', 'u'), ('braku', 'braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# [('u', 'u'), ('braku', 'braku'), ('smo', 'smo'), ('već', 'već'), ('devet', 'devet'), ('godina', 'godina')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK27T__19-04-21-09-54-19_transcript.txt
# za osam minuta počinje prestao
# [('za', 'za'), ('osam', 'osam'), ('minuta', 'minuta'), ('počinje', 'počinje')]
# [('za', 'za'), ('osam', 'osam'), ('minuta', 'minuta'), ('počinje', 'počinje'), ('prestao', 'predstava')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK28T__19-04-21-09-54-42_transcript.txt
# večeras mora da donese odluku o njegovoj smeni
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# [('večeras', 'večeras'), ('mora', 'mora'), ('da', 'da'), ('donese', 'donese'), ('odluku', 'odluku'), ('o', 'o'), ('njegovoj', 'njegovoj'), ('smeni', 'smeni')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK29T__19-04-21-09-55-01_transcript.txt
# o tvoja fer i novine su pisale danima
# [('o', 'o'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# [('o', 'o'), ('novine', 'novine'), ('su', 'su'), ('pisale', 'pisale'), ('danima', 'danima')]
# /content/drive/MyDrive/PhD/Forced_alignment/transcript/1052_Resampled/4/4_4_1_SKMK30T__19-04-21-09-55-20_transcript.txt
# dugo vremena nismo ovde bili
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# [('dugo', 'dugo'), ('vremena', 'vremena'), ('nismo', 'nismo'), ('ovde', 'ovde'), ('bili', 'bili')]
# Number of errors: 7
